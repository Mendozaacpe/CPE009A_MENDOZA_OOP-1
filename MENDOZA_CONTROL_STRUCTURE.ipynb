# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendozaacpe/CPE009A_MENDOZA_OOP-1/blob/main/MENDOZA_CONTROL_STRUCTURE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NAME:** Mendoza, Allyson E.
#
# **SECTION:** CPE12S2
#
# **PROGRAM:** BSCPE

# %% [markdown]
# ***If Statement***

# %%
a = 12
b = 100
if b > a:
  print ("b is greater then a")
# Out:
# b is greater then a

# %% [markdown]
# ***Elif Statement***

# %%
a = 12
b = 12
if b > a:
  print ("b is greater than a")
elif a==b:
    print ("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# ***Else Statement***

# %%
a = 200
b = 33
if b > a:
  print ("b is greater than a")
elif a==b:
  print ("a and b are equal")
else:
  print ("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ***Short Hand If Statement***

# %%
if a > b:
  print ("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ***Short Hand If...Else Statement***

# %%
a = 2
b = 330
print ("A") if a > b else print ("B")
# Out:
# B

# %% [markdown]
# ***And-Both Conditions are True***

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print ("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# ***Or-At Least one of the Conditions is True***

# %%
a = 200
b = 33
c = 500
if a > b or c > a:
  print ("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# ***Nested If***

# %%
x = 41

if x > 10:
  print ("Above ten,")
  if x > 20:
    print ("and also above 20!")
    if x > 30:
      print ("and also above 30!")
      if x > 40:
        print ("and also above 40!")
        if x > 50:
          print ("and also above 50!")
        else:
          print ("below 50.")
      else:
        print ("below 40.")
    else:
      print ("below 30.")
  else:
    print ("below 20.")
else:
    print ("below 10.")

#PLUS 5 POINTS
# Out:
# Above ten,
# and also above 20!
# and also above 30!
# and also above 40!
# below 50.

# %% [markdown]
# ***SUPPLEMENTARY ACTIVITY - EXAMPLE ***

# %%
print ("Enter a number")
x = int(input())

if x >= 75:
  print ("PASSED")
if x == 74:
  print ("REMEDIAL")
if x < 74:
  print ("FAILED")

#PLUS 5 POINTS
# Out:
# Enter a number
# 70
# FAILED
