# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendozaacpe/CPE009A_MENDOZA_OOP-1/blob/main/MENDOZA_ALLYSON_CPE009_S1_Seatwork_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(0, actNumber):
    inputScore = float(input("Score: "))
    inputTotal = float(input("Total: "))

    if inputScore > inputTotal:
      print("\nInvalid Scores.\n")
      inputScore, inputTotal = 0,0
      break
    else:
      rawScore.append(inputScore)
      totalScore.append(inputTotal)

  grade = sum(rawScore) / sum(totalScore)
  return grade

# %%
# Create a function for the class standing per term
def termCS():
  print("\nHands-on Activities: ")
  termHOA = termCrit(int(input("How many hands-on activities this term? ")))

  print("\nQuizzes:")
  termQuiz = termCrit(int(input("How many quizzes this term? ")))

  print("\nAssignment: ")
  termAss = termCrit(int(input("How many assignments? ")))

  print ("\nYour Class Standing for this term is: ")
  termCS = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return termCS

# %%
# Create a function to compute the term grade
def termGrade():
  print("\nComputing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  examGrade = (examRaw/examTotal) * 100

  CSGrade = termCS

  termGrade = (0.5 * examGrade) + (0.5 * CSGrade)
  return termGrade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("Prelim Grade")
  prelimGrade = termGrade()

  print("Midterm Grade")
  midtermGrade = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("Final Grade")
  finalGrade = (1/3)*finalGrade + (2/3)*finalGrade

  print ("Your semester grade is: ")
  semesterGrade = finalGrade
  return semesterGrade

# %%
def convertGrade(finalGrade):
  print(termCS)
  print(termGrade)
  print(semesterGrade)

  if finalGrade >= 99: print ("1.00")
  elif finalGrade >= 96: print ("1.25")
  elif finalGrade >= 93: print ("1.50")
  elif finalGrade >= 90: print ("1.75")
  elif finalGrade >= 87: print ("2.00")
  elif finalGrade >= 84: print ("2.25")
  elif finalGrade >= 81: print ("2.50")
  elif finalGrade >= 78: print ("2.75")
  elif finalGrade >= 75: print ("3.00")
  #The class should add everything else

# %%
# Driver Code

# Trial 1
print(convertGrade(semesterGrade))

# Trial 2

# Trial 3
# Out:
# <function termCS at 0x7c013498e0c0>
# <function termGrade at 0x7c013498db20>
# <function semesterGrade at 0x7c013498de40>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-307928750.py in <cell line: 0>()
#       2
#       3 # Trial 1
# ----> 4 print(convertGrade(semesterGrade))
#       5
#       6 # Trial 2
#
# /tmp/ipython-input-1864709199.py in convertGrade(finalGrade)
#       4   print(semesterGrade)
#       5
# ----> 6   if finalGrade >= 99: print ("1.00")
#       7   elif finalGrade >= 96: print ("1.25")
#       8   elif finalGrade >= 93: print ("1.50")
#
# TypeError: '>=' not supported between instances of 'function' and 'int'

# %% [markdown]
# **What is the difference from the code you created?**
#
# <Answer here>

# %% [markdown]
# - The difference that I made is that I added a percentage to the average of each semester but there are some problems and it can't direct to that specific semester even though that I stated the "semesterGrade" in the converted Grade. Also, I added a point grade in order for it to be converted.
