# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendozaacpe/CPE009A_MENDOZA_OOP-1/blob/main/MIDTERM_EXAM_MENDOZA%2C_ALLYSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUESTION 23**

# %% [markdown]
# Write a program that uses nested loops to print this pattern:
#
# ###*
# ###**
# ###***
# ###****
# ###*****
# ###****
# ###***
# ###**
# ###*

# %%
asterisk = ("*")
number = [1, 2, 3, 4, 5]

for x in number:
  if x == 1 in number:
    print ("*")
  elif x == 2 in number:
    print ("**")
  elif x == 3 in number:
    print ("***")
  elif x == 4 in number:
    print("****")
  elif x == 5 in number:
    print ("*****")

if x <= 5 in number:
  print("****")
  print("***")
  print("**")
  print("*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# **QUESTION 24**

# %% [markdown]
# Write a function that checks if a string of parentheses (), brackets [], and braces {} is balanced.
#
# Examples:
#
#     "({[]})" → True
#
#     "([)]" → False
#
#     "((()))" → True
#
#     "({)}" → False

# %%
symbols = () , {} , []

combination1 = "({[]})"
combination2 = "([)]"
combination3 = "((()))"
combination4 = "({)}"

if combination1 == print("True"):
  if combination2 == print("Fasle"):
    if combination3 == print("True"):
      if combination4:
        print("False")
# Out:
# True
