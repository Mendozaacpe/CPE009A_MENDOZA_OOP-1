# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendozaacpe/CPE009A_MENDOZA_OOP-1/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Indentation**

# %%
if 5 > 2:
  print ("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# **Python Comments**

# %%
#This is a comment
print ("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Variable Naming Conventions**

# %% [markdown]
# **Python Variable**

# %%
x = 1
a, b = 0, -1
a, b, c = 0, -1, 2

b = "Sally" #This is a type of string

print ("Sally")
# Out:
# Sally

# %% [markdown]
# **Casting**

# %%
b = "sally" #This is a type of string
b = int(4)
print (b)

b = float(4)
print (b)
# Out:
# 4
# 4.0

# %% [markdown]
# **Type() Function**

# %%
x = 5
y = "John"

print (type(x))
print (type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# **"Double Quotes" or "Single Quotes"**

# %%
y = "John"
y = 'John'

print (y)
# Out:
# John

# %% [markdown]
# **Case Sensitive**

# %%
a = 4
A = "Sally"
#A will not overwrite a

print (a)
print (A)
# Out:
# 4
# Sally

# %% [markdown]
# **Multiple Variables**

# %%
x, y, z = "one", "two", "three"

print (x)
print (y)
print (z)
# Out:
# one
# two
# three

# %% [markdown]
# **One Value to Multiple Variables**

# %%
x = y = z = "four"

print (x)
print (y)
print (z)
# Out:
# four
# four
# four

# %% [markdown]
# **Output Variables**

# %%
x = "enjoying"
print ("Python programming is " + x)
# Out:
# Python programming is enjoying

# %% [markdown]
# **Other way:**

# %%
x = "Python is "
y = "enjoying"
z = x + y

print (z)
# Out:
# Python is enjoying

# %% [markdown]
# **Arithmetic Operations**

# %%
x = 5
y = 3

sum = x + y
sum
print (x + y)
print (x - y)
print (x * y)
print (x / y)
print (x % y)
print (x ** y)
print (x // y)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 125
# 1

# %% [markdown]
# **Assignment Operators**

# %%
s = 1

s += 3
print (s)

s -= 3
print (s)

s *= 3
print (s)

s /= 3
print (s)

s %= 3
print (s)

s **= 3
print (s)

s //= 3
print (s)

s = int(s)
s &= 3
print (s)

s |= 3
print (s)

s ^= 3
print (s)

s >>= 3
print (s)

s <<= 3
print (s)
# Out:
# 4
# 1
# 3
# 1.0
# 1.0
# 1.0
# 0.0
# 0
# 3
# 0
# 0
# 0

# %% [markdown]
# **Comparison Operators**

# %%
t = 1
u = 2


print (t == u)
print (t != u)
print (t > u)
print (t < u)
print (t >= u)
print (t <= u)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# **Logical Operators**

# %%
t = 1
u = 2

print (t < 5 and u < 10)
print (t < 5 or u < 4)
print (not (t < 5 and x < 10))
# Out:
# True
# True
# False

# %% [markdown]
# **Identity Operators**

# %%
t = 1
u = 2

print (t is u)
print (t is not u)
# Out:
# False
# True

# %% [markdown]
# **Bitwise Operators**

# %%
t = 1
u = 2

print (t & u)
print (t | u)
print (t ^ u)
print (t, ~ u)
print (t << u)
print (t >> u)
# Out:
# 0
# 3
# 3
# 1 -3
# 4
# 0
