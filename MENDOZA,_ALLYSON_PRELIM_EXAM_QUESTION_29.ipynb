# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendozaacpe/CPE009A_MENDOZA_OOP-1/blob/main/MENDOZA%2C_ALLYSON_PRELIM_EXAM_QUESTION_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Develop a python scripts that:
#
#     Calculate total marks and percentage
#     Assign grade for each subject based on marks:
#
# 90-100: A+
#
# 80-89: A
#
# 70-79: B+
#
# 60-69: B
#
# 50-59: C
#
# 40-49: D
#
# Below 40: F (Fail)
#
#     Determine overall result (Pass/Fail)
#
#
#
# Performance Remarks:
#
#
# Percentage ≥ 90: "Outstanding"
#
# Percentage ≥ 80: "Excellent"
#
# Percentage ≥ 70: "Very Good"
#
# Percentage ≥ 60: "Good"
#
# Percentage ≥ 40: "Satisfactory"
#
# Below 40: "Needs Improvement"

# %%
#Assign grade for each subject based on marks:

def marks(grade):

    print("MATH_019") == input("Enter your marks: ")
    print("MATH_013") == input("Enter your marks: ")
    print("EMATH_017") == input("Enter your marks: ")
    print("GEC_004") == input("Enter your marks: ")
    print("PHYS_001C") == input("Enter your marks: ")
    print("CPE_003A") == input("Enter your marks: ")
    print("CPE_009A") == input("Enter your marks: ")
    print("GEE_001") == input("Enter your marks: ")
    print("PE_002") == input("Enter your marks: ")
    print("NSTP_002") == input("Enter your marks: ")
    total_marks = 100

    if marks >= 90: print ("A+")
    elif marks >= 80: print ("A")
    elif marks >= 70: print ("B+")
    elif marks >= 60: print ("B")
    elif marks >= 50: print ("C")
    elif marks >= 40: print ("D")
    else: print ("F")

def percentage(marks):
    total_marks = 100

    percentage = (marks/total_marks*100)
    print(percentage)

    if percentage >= 90: print ("Outstanding")
    elif percentage >= 80: print ("Excellent")
    elif percentage >= 70: print ("Very Good")
    elif percentage >= 60: print ("Good")
    elif percentage >= 40: print ("Satisfactory")
    else: print ("Needs Improvement")

# %%
# Driver Code

#Trial 1
print(marks(percentage))

#Trial
# Out:
# MATH_019
# Enter your marks: 89
# MATH_013
# Enter your marks: 89
# EMATH_017
# Enter your marks: 90
# GEC_004
# Enter your marks: 90
# PHYS_001C
# Enter your marks: 90
# CPE_003A
# Enter your marks: 90
# CPE_009A
# Enter your marks: 90
# GEE_001
# Enter your marks: 92
# PE_002
# Enter your marks: 95
# NSTP_002
# Enter your marks: 97
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2176813729.py in <cell line: 0>()
#       2
#       3 #Trial 1
# ----> 4 print(marks(percentage))
#       5
#       6 #Trial 2
#
# /tmp/ipython-input-1498381677.py in marks(grade)
#      15     total_marks = 100
#      16
# ---> 17     if marks >= 90: print ("A+")
#      18     elif marks >= 80: print ("A")
#      19     elif marks >= 70: print ("B+")
#
# TypeError: '>=' not supported between instances of 'function' and 'int'
